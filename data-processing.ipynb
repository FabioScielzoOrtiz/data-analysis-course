# %% [markdown]
# # **Data processing**

# %% [markdown]
# ## Requirements

# %%
import polars as pl
pl.Config(fmt_str_lengths=50)
pl.Config(tbl_rows=30)
import warnings
# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
def has_dot(x):
    return x.find('.') != -1

def has_comma(x):
    return x.find(',') != -1

def reformat_str_number(x):

    # This functions is suppose to implement the following transformations:
    # '10554' --> '10554'
    # '10.554' --> '10554' (to be cast into integer or float)
    # '10.554.00' --> '10554' (to be cast into integer or float) 
    # '10,554' --> '10.554' (to be cast into float)
    # '10.554,75' --> '10554.75' (to be cast into float) 

    if has_comma(x):
        if not has_dot(x):
            return x.replace(',', '.')
        if has_dot(x):
            return ''.join(x.split(',')[0].split('.')) +'.'+ x.split(',')[1]
    elif has_dot(x) :
        if len(x.split('.')) > 2:
            return ''.join(x.split('.')[:2])
        else:
            return ''.join(x.split('.'))
    else: # number without ',' and '.'
        return  x

# %% [markdown]
# ## Reading the data

# %%
madrid_df = pl.read_csv(r'C:\Users\fscielzo\Documents\Teaching\data-analysis-course\data\indicadores_distritos_barrios.csv', 
                        separator=';', ignore_errors=True)

# %%
madrid_df.head()
# Out:
# shape: (5, 18)
# ┌───────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Orden ┆ Periodo    ┆ ciudad     ┆ cod_distri ┆ … ┆ indicador ┆ unidad_in ┆ indicador ┆ valor_ind │
# │ ---   ┆ panel      ┆ ---        ┆ to         ┆   ┆ _nivel3   ┆ dicador   ┆ _completo ┆ icador    │
# │ i64   ┆ ---        ┆ str        ┆ ---        ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │       ┆ i64        ┆            ┆ str        ┆   ┆ str       ┆ str       ┆ str       ┆ str       │
# ╞═══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1     ┆ 2020       ┆ Ciudad de  ┆ null       ┆ … ┆ null      ┆ Ha        ┆ Superfici ┆ 60.446    │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆           ┆ e (Ha.)   ┆           │
# │ 2     ┆ 2020       ┆ Ciudad de  ┆ null       ┆ … ┆ null      ┆ Habitante ┆ Población ┆ 54        │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆ s/Ha.     ┆ densidad  ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ (hab./Ha. ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ )         ┆           │
# │ 3     ┆ 2020       ┆ Ciudad de  ┆ null       ┆ … ┆ null      ┆ Habitante ┆ Número    ┆ 3.266.126 │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆ s         ┆ Habitante ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ s         ┆           │
# │ 4     ┆ 2020       ┆ Ciudad de  ┆ null       ┆ … ┆ null      ┆ Habitante ┆ Población ┆ 1.521.178 │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆ s         ┆ Hombres   ┆           │
# │ 5     ┆ 2020       ┆ Ciudad de  ┆ null       ┆ … ┆ null      ┆ Habitante ┆ Población ┆ 1.744.948 │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆ s         ┆ Mujeres   ┆           │
# └───────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
madrid_df.tail()
# Out:
# shape: (5, 18)
# ┌───────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Orden ┆ Periodo    ┆ ciudad     ┆ cod_distri ┆ … ┆ indicador ┆ unidad_in ┆ indicador ┆ valor_ind │
# │ ---   ┆ panel      ┆ ---        ┆ to         ┆   ┆ _nivel3   ┆ dicador   ┆ _completo ┆ icador    │
# │ i64   ┆ ---        ┆ str        ┆ ---        ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │       ┆ i64        ┆            ┆ str        ┆   ┆ str       ┆ str       ┆ str       ┆ str       │
# ╞═══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 69171 ┆ 2020       ┆ Ciudad de  ┆ 21         ┆ … ┆ null      ┆ Índice    ┆ Grado de  ┆ 7,2       │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆           ┆ satisfacc ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ ión con   ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ los       ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ espacios  ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ verdes    ┆           │
# │ 69172 ┆ 2020       ┆ Ciudad de  ┆ 21         ┆ … ┆ null      ┆ Índice    ┆ Grado de  ┆ 6,6       │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆           ┆ satisfacc ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ ión con   ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ los       ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ parques   ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ infantile ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ s         ┆           │
# │ 69173 ┆ 2020       ┆ Ciudad de  ┆ 21         ┆ … ┆ null      ┆ Índice    ┆ Grado de  ┆ 7,3       │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆           ┆ satisfacc ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ ión con   ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ los       ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ centros   ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ culturale ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ s         ┆           │
# │ 69174 ┆ 2020       ┆ Ciudad de  ┆ 21         ┆ … ┆ null      ┆ Índice    ┆ Grado de  ┆ 6,4       │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆           ┆ satisfacc ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ ión con   ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ las insta ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ laciones  ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ deport…   ┆           │
# │ 69175 ┆ 2020       ┆ Ciudad de  ┆ 21         ┆ … ┆ null      ┆ Índice    ┆ Grado de  ┆ 6,7       │
# │       ┆            ┆ Madrid     ┆            ┆   ┆           ┆           ┆ satisfacc ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ ión de    ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ los       ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ servicios ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ sociales  ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ mu…       ┆           │
# └───────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Pivoting

# %%
madrid_df = madrid_df.select(['ciudad', 'distrito', 'barrio', 'año', 'indicador_completo', 'valor_indicador'])\
                     .pivot(
                           index=['ciudad',"distrito", "barrio", "año"],
                           on="indicador_completo",
                           values="valor_indicador",
                           aggregate_function = 'first'
                         )

# %%
madrid_df.head(10)
# Out:
# shape: (10, 416)
# ┌─────────────┬──────────┬──────────┬──────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ ciudad      ┆ distrito ┆ barrio   ┆ año  ┆ … ┆ Índice de  ┆ Índice de  ┆ Índice de  ┆ Índice de  │
# │ ---         ┆ ---      ┆ ---      ┆ ---  ┆   ┆ Vulnerabil ┆ Vulnerabil ┆ Vulnerabil ┆ Vulnerabil │
# │ str         ┆ str      ┆ str      ┆ i64  ┆   ┆ idad       ┆ idad       ┆ idad Medio ┆ idad Salud │
# │             ┆          ┆          ┆      ┆   ┆ Economía y ┆ Educación  ┆ Ambiente   ┆ ---        │
# │             ┆          ┆          ┆      ┆   ┆ Empleo     ┆ y Cultura  ┆ Urbano y   ┆ str        │
# │             ┆          ┆          ┆      ┆   ┆ ---        ┆ ---        ┆ M…         ┆            │
# │             ┆          ┆          ┆      ┆   ┆ str        ┆ str        ┆ ---        ┆            │
# │             ┆          ┆          ┆      ┆   ┆            ┆            ┆ str        ┆            │
# ╞═════════════╪══════════╪══════════╪══════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ Ciudad de   ┆ null     ┆ null     ┆ 2019 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ null     ┆ null     ┆ 2018 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ null     ┆ null     ┆ 2016 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ null     ┆ null     ┆ 2008 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ null     ┆ null     ┆ 2020 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ null     ┆ null     ┆ 2013 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ Centro   ┆ null     ┆ 2019 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ Centro   ┆ null     ┆ 2018 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ Centro   ┆ null     ┆ 2020 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# │ Ciudad de   ┆ Centro   ┆ Justicia ┆ 2020 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ Madrid      ┆          ┆          ┆      ┆   ┆            ┆            ┆            ┆            │
# └─────────────┴──────────┴──────────┴──────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
madrid_df.tail(10)
# Out:
# shape: (10, 416)
# ┌────────────┬────────────┬────────────┬──────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ ciudad     ┆ distrito   ┆ barrio     ┆ año  ┆ … ┆ Índice de  ┆ Índice de ┆ Índice de ┆ Índice de │
# │ ---        ┆ ---        ┆ ---        ┆ ---  ┆   ┆ Vulnerabil ┆ Vulnerabi ┆ Vulnerabi ┆ Vulnerabi │
# │ str        ┆ str        ┆ str        ┆ i64  ┆   ┆ idad       ┆ lidad     ┆ lidad     ┆ lidad     │
# │            ┆            ┆            ┆      ┆   ┆ Economía y ┆ Educación ┆ Medio     ┆ Salud     │
# │            ┆            ┆            ┆      ┆   ┆ Empleo     ┆ y Cultura ┆ Ambiente  ┆ ---       │
# │            ┆            ┆            ┆      ┆   ┆ ---        ┆ ---       ┆ Urbano y  ┆ str       │
# │            ┆            ┆            ┆      ┆   ┆ str        ┆ str       ┆ M…        ┆           │
# │            ┆            ┆            ┆      ┆   ┆            ┆           ┆ ---       ┆           │
# │            ┆            ┆            ┆      ┆   ┆            ┆           ┆ str       ┆           │
# ╞════════════╪════════════╪════════════╪══════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ Ciudad de  ┆ San Blas-C ┆ El         ┆ 2023 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆ anillejas  ┆ Salvador   ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ Barajas    ┆ null       ┆ 2023 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆            ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ Barajas    ┆ Alameda de ┆ 2023 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆            ┆ Osuna      ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ Barajas    ┆ Aeropuerto ┆ 2023 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆            ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ Barajas    ┆ Casco      ┆ 2023 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆            ┆ Histórico  ┆      ┆   ┆            ┆           ┆           ┆           │
# │            ┆            ┆ de Barajas ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ Barajas    ┆ Timón      ┆ 2023 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆            ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ Barajas    ┆ Corralejos ┆ 2023 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆            ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ Villaverde ┆ Los        ┆ 2022 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆            ┆ Ángeles    ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ Vicálvaro  ┆ Casco      ┆ 2022 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆            ┆ histórico  ┆      ┆   ┆            ┆           ┆           ┆           │
# │            ┆            ┆ de         ┆      ┆   ┆            ┆           ┆           ┆           │
# │            ┆            ┆ Vicálvaro  ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ San Blas-C ┆ Salvador   ┆ 2022 ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆ anillejas  ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴──────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Column display

# %%
madrid_df.columns
# Out:
# ['ciudad',
#  'distrito',
#  'barrio',
#  'año',
#  'Superficie (Ha.) ',
#  'Población densidad (hab./Ha.) ',
#  'Número Habitantes',
#  'Población Hombres ',
#  'Población Mujeres',
#  'Edad media de la población',
#  'Población de 0 a 14 años   ',
#  'Población de 15 a 29 años',
#  'Población de 30 a 44  años',
#  'Población de 45 a 64 años',
#  'Población de 65 a 79 años      ',
#  'Población de 80 años y más           ',
#  'Población de 65 años y más          ',
#  'Población en etapa educativa (Población de 0 a 16 años -16 no incluidos)                            ',
#  'Proporción de envejecimiento (Población mayor de 65 años/Población total)',
#  'Proporción de sobre-envejecimiento (Población mayor de 80 años/ Población mayor de 65 años)',
#  'Índice de dependencia (Población de 0-15 + población 65 años y más / Pob. 16-64) ',
#  'Personas con nacionalidad española             ',
#  'Personas con nacionalidad española Hombres                      ',
#  'Personas con nacionalidad española Mujeres                      ',
#  'Personas con nacionalidad extranjera            ',
#  'Personas con nacionalidad extranjera Hombres                       ',
#  'Personas con nacionalidad extranjera Mujeres                        ',
#  'Proporción de personas migrantes (Población extranjera menos UE y resto países de OCDE / Población total)',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nITALIA (Población total Distrito)',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nBANGLADESH (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nCHINA (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nVENEZUELA (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nRUMANÍA (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nBOLIVIA (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nECUADOR (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nFILIPINAS (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nFRANCIA (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nMARRUECOS (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nPARAGUAY (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nPERÚ (Población total Distrito) ',
#  'Total hogares',
#  'Tamaño medio del hogar      ',
#  'Hogares con una mujer sola mayor de 65 años                      ',
#  'Hogares con un hombre solo mayor de 65 años                     ',
#  'Hogares monoparentales: una mujer adulta con uno o más menores',
#  'Hogares monoparentales: un hombre adulto con uno o más menores',
#  'Tasa de crecimiento demográfico (porcentaje)',
#  'Esperanza de vida al nacer Mujeres (mortalidad del periodo 2013-2016)',
#  'Esperanza de vida al nacer Hombres  (mortalidad del periodo 2013-2016)',
#  'Esperanza de vida al nacer Mujeres',
#  'Esperanza de vida al nacer Hombres ',
#  'Esperanza de vida mayor de 65 años Mujeres',
#  'Esperanza de vida mayor de 65 años Hombres',
#  'Índice de desigualdad de género',
#  'Índice de desigualdad de género (1)',
#  'Renta neta media anual de los hogares (Urban Audit)             ',
#  'Renta disponible media por persona',
#  'Crecimiento/decrecimiento Renta Bruta Per cápita 2016(a)-2008',
#  'Pensión media mensual Hombres ',
#  'Pensión media mensual  Mujeres\n',
#  'Tasa de actividad global ciudad de Madrid',
#  'Tasa de actividad global en Hombres ',
#  'Tasa de actividad global en Mujeres',
#  'Número de personas paradas ciudad de Madrid (EPA. 4º trimestre) (miles)',
#  'Número de hombres parados en la ciudad de Madrid (EPA. 4º trimestre) (miles)',
#  'Número de mujeres paradas en la ciudad de Madrid (EPA. 4º trimestre) (miles)',
#  'Paro registrado (número de personas registradas en SEPE en febrero) ',
#  'Paro registrado (número de personas registradas en SEPE en febrero) hombres    ',
#  'Paro registrado (número de personas registradas en SEPE en febrero) mujeres',
#  'Tasa absoluta de paro registrado (febrero)',
#  'Tasa absoluta de paro registrado Mujeres',
#  'Tasa de desempleo en mujeres de 16 a 24 años',
#  'Tasa de desempleo en mujeres de 25 a 44 años',
#  'Tasa de desempleo en mujeres de 45 a 64 años',
#  'Tasa absoluta de paro registrado Hombres ',
#  'Tasa de desempleo en hombres de 16 a 24 años',
#  'Tasa de desempleo en hombres de 25 a 44 años',
#  'Tasa de desempleo en hombres de 45 a 64 años',
#  'Personas paradas de larga duración (febrero)              ',
#  'Personas paradas de larga duración (febrero) hombres                         ',
#  'Personas paradas de larga duración (febrero) mujeres                            ',
#  'Personas paradas que SÍ perciben prestaciones (febrero)',
#  'Personas paradas que SÍ perciben prestaciones (febrero) hombres                         ',
#  'Personas paradas que SÍ perciben prestaciones (febrero) mujeres                         ',
#  'Personas paradas que NO perciben prestaciones (febrero)',
#  'Personas paradas que NO perciben prestaciones (febrero) hombres          ',
#  'Personas paradas que NO perciben prestaciones (febrero) mujeres          ',
#  'Población en etapas educativas',
#  'Población en etapa educativa de 0 a 2 años',
#  'Población en etapa educativa de 3 a 5 años',
#  'Población en etapa educativa de 6 a 11 años',
#  'Población en etapa educativa de 12 a 15 años',
#  'Etapas educativas. Total niños',
#  'Población infantil masculina en etapa educativa de 0 a 2 años',
#  'Población infantil masculina en etapa educativa de 3 a 5 años',
#  'Población infantil masculina en etapa educativa de 6 a 11 años',
#  'Población infantil masculina en etapa educativa de 12 a 15 años',
#  'Etapas educativas. Total niñas',
#  'Población infantil femenina en etapa educativa de 0 a 2 años',
#  'Población infantil femenina en etapa educativa de 3 a 5 años',
#  'Población infantil femenina en etapa educativa de 6 a 11 años',
#  'Población infantil femenina en etapa educativa de 12 a 15 años',
#  'Escolarización del alumnado por tipo de centro ',
#  'Alumnado en Centros privados concertados',
#  'Alumnado en Centros privados sin concierto',
#  'Alumnado en Centros públicos',
#  'Total alumnado extranjero ',
#  'Alumnado extranjero en Centros privados concertados                   ',
#  'Alumnado extranjero en Centros privados sin concierto                  ',
#  'Alumnado extranjero en Centros públicos                        ',
#  'Total alumnado con necesidades de apoyo educativo  ',
#  'Alumnado con necesidades de apoyo educativo en Centros privados concertados                   ',
#  'Alumnado con necesidades de apoyo educativo en Centros privados sin concierto                  ',
#  'Alumnado con necesidades de apoyo educativo en Centros públicos                        ',
#  'Población mayor/igual  de 25 años  que no sabe leer ni escribir o sin estudios                ',
#  'Población mayor/igual  de 25 años con enseñanza primaria incompleta  ',
#  'Población mayor/igual  de 25 años con Bachiller Elemental, Graduado Escolar, ESO, Formación profesional 1º grado  ',
#  'Población mayor/igual  de 25 años con Formación profesional 2º grado, Bachiller Superior o BUP  ',
#  'Población mayor/igual  de 25 años con titulación media, diplomatura, arquitectura o ingeniería técnica    ',
#  'Población mayor/igual  de 25 años  con estudios superiores, licenciatura, arquitectura, ingeniería sup., estudios sup. no universitarios, doctorado,  postgraduado  ',
#  'Población mayor/igual  de 25 años con Nivel de estudios desconocido y/o no consta                                   ',
#  'Casos trabajados por el programa de absentismo municipal',
#  'Casos trabajados por el programa de absentismo municipal Hombres               ',
#  'Casos trabajados por el programa de absentismo municipal Mujeres               ',
#  'Número de personas con grado de discapacidad reconocido                               ',
#  'Número de personas con grado de discapacidad reconocido Hombres                                    ',
#  'Número de personas con grado de discapacidad reconocido Mujeres                                    ',
#  'Mujeres por cada 100 hombres (Feminización de la discapacidad reconocida)',
#  'Satisfacción de vivir en su barrio ',
#  'Calidad de vida actual en su barrio ',
#  'Satisfacción de la convivencia vecinal ',
#  'Grado de satisfacción con la organización de fiestas y eventos populares',
#  'Percepción de desigualdad en las dotaciones de los barrios   (sumando las categorías "muy alta" + "alta")',
#  'Tres principales problemas en espacios públicos: 1ºLimpieza',
#  'Tres principales problemas en espacios públicos: 2ºContaminación del aire',
#  'Tres principales problemas en espacios públicos: 3ºTráfico / atascos',
#  'Percepción de seguridad en Madrid',
#  'Percepción de seguridad en el barrio por el día',
#  'Percepción de seguridad en el barrio por la noche',
#  'Tres principales problemas en espacios públicos: 1ºPersonas orinando en la calle',
#  'Tres principales problemas en espacios públicos: 2ºExcrementos animales domésticos',
#  'Tres principales problemas en espacios públicos: 3ºConsumo o menudeo de drogas',
#  'Tres principales problemas en espacios públicos: 1ºExcrementos animales domésticos',
#  'Tres principales problemas en espacios públicos: 2ºConductas que ponen en riesgo la seguridad vial',
#  'Tres principales problemas en espacios públicos: 3ºPersonas orinando en la calle',
#  'Tres principales problemas en espacios públicos: 3ºExceso de velocidad',
#  'Tres principales problemas en espacios públicos: 2ºRobos, atracos y hurtos',
#  'Tres principales problemas en espacios públicos: 3ºConductas que ponen en riesgo la seguridad vial',
#  'Tres principales problemas en espacios públicos: 2ºPersonas orinando en la calle',
#  'Tres principales problemas en espacios públicos: 3ºMolsetias por ruido',
#  'Tres principales problemas en espacios públicos: 2ºBotellón',
#  'Tres principales problemas en espacios públicos: 3ºGrafitis',
#  'Tres principales problemas en espacios públicos: 2ºGrafitis',
#  'Tres principales problemas en espacios públicos: 3ºRobos, atracos y hurtos',
#  'Tres principales problemas en espacios públicos: 2ºConsumo o menudeo de drogas',
#  'Tres principales problemas en espacios públicos: 3ºEstacionamientos indebidos',
#  'Tres principales problemas en espacios públicos: 2ºEstacionamientos indebidos',
#  'Tres principales problemas en espacios públicos: 3ºUso indebido de parques y espacios públicos',
#  'Tres principales problemas en espacios públicos: 2ºExceso de velocidad',
#  'Preferencia de contacto con el Ayuntamiento: EN PERSONA',
#  'Percepción sobre la administración del Ayto. en los últimos 5 años: HA MEJORADO',
#  'Percepción sobre la administración del Ayto. en los últimos 5 años: HA EMPEORADO',
#  'Tasa de riesgo de pobreza o exclusión social',
#  'Tasa de riesgo de pobreza o exclusión social Hombres',
#  'Tasa de riesgo de pobreza o exclusión social Mujeres',
#  'Tasa de riesgo de pobreza o exclusión social ESPAÑOLA (mayor de 16 años)',
#  'Tasa de riesgo de pobreza o exclusión social EXTRANJERA UNIÓN EUROPEA (mayor de 16 años)',
#  'Tasa de riesgo de pobreza o exclusión social EXTRANJERA RESTO DEL MUNDO (mayor de 16 años)',
#  'Personas atendidas en la Unidad de Primera Atención en Centros de Servicios Sociales          ',
#  'Solicitudes tramitadas de Renta Mínima de Inserción',
#  'Personas perceptoras de prestación de la Renta Mínima de Inserción',
#  'Personas beneficiarias de prestaciones sociales de carácter económico',
#  'Total prestaciones sociales de carácter económico ',
#  'Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar)  ',
#  'Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar) Hombres                                 ',
#  'Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar) Mujeres                              ',
#  'Personas socias de los Centros Municipales de Mayores',
#  'Personas socias de los Centros Municipales de Mayores Hombres                      ',
#  'Personas socias de los Centros Municipales de Mayores Mujeres             ',
#  'Familias atendidas por el Equipo de Trabajo con Menores y Familia (ETMF) ',
#  'Demandas de intervención en los Centros de Atención a la Infancia (CAI)',
#  'Menores atendidos por el Servicio de Ayuda a domicilio a Menores y Familias (SAF)',
#  'Número Total de viviendas (Censo Edificios y Viviendas 2011)',
#  'Viviendas anteriores a 1980                                                                 ',
#  'Viviendas en estado ruinoso',
#  'Viviendas en estado malo ',
#  'Viviendas en estado deficiente  ',
#  'Viviendas en estado bueno ',
#  'Estado de la vivienda no consta ',
#  'Valor catastral medio de los bienes inmuebles: personas físicas en miles de € ',
#  'Valor catastral medio de los bienes inmuebles: personas jurídicas en miles de €',
#  'Superficie media de la vivienda (m2) en transacción                    ',
#  'Duración media del crédito (meses) en transacción de vivienda ',
#  'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) ',
#  'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) Principal                           ',
#  'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Secundaria                           ',
#  'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Población desocupada    ',
#  'Lanzamientos judiciales practicados (1)',
#  'Lanzamientos judiciales como consecuencia de ejecuciones hipotecarias (1)',
#  'Lanzamientos judiciales consecuencia de la Ley de Arrendamientos Urbanos (1)',
#  'Lanzamientos judiciales practicados ',
#  'Lanzamientos judiciales como consecuencia de ejecuciones hipotecarias ',
#  'Lanzamientos judiciales consecuencia de la Ley de Arrendamientos Urbanos ',
#  'Partículas suspensión PM2.5 (µgr/m3)',
#  'Partículas suspensión PM10 (µgr/m3) ',
#  'Dióxido de azufre - SO2 (µgr/m3) ',
#  'Monóxido de carbono - CO  (mg/m3)',
#  'Ozono - O3 (µgr/m3) ',
#  'Dióxido de nitrógeno - NO2 (µgr/m3)',
#  'Temperatura media anual (ºC)',
#  'Protocolo de contaminación: número de episodios ',
#  'Protocolo de contaminación: número de días "Escenario 1" ',
#  'Recogida domiciliaria residuos sólidos: envases y resto kg/habitante/año',
#  'Recogida domiciliaria residuos sólidos: envases y resto kg/habitante/día',
#  'Intervenciones de la Policía Municipal en materia de seguridad: delitos relacionados con las personas',
#  'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia de armas',
#  'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con el patrimonio',
#  'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia y consumo de drogas',
#  'Expedientes instruidos por Agentes Tutores',
#  'Atestados/partes de accidentes de tráfico confeccionados',
#  'Personas detenidas e investigadas por la Policía Municipal en materia de seguridad: Total  personas detenidas e investigadas ',
#  'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Lesiones',
#  'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Violencia doméstica y de género',
#  'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Malos tratos a menores',
#  'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Abusos y agresiones sexuales ',
#  'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Hurtos',
#  'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Robo con violencia e intimidación en personas',
#  'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Contra la salud pública  ',
#  'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Contra la seguridad vial  ',
#  'Elecciones municipales, censo electoral',
#  'Elecciones municipales, abstenciones',
#  'Elecciones  municipales, votos en blanco',
#  'Elecciones municipales, votos a candidaturas',
#  'Elecciones municipales, votos a Más Madrid',
#  'Elecciones municipales, votos al Partido Popular',
#  'Elecciones municipales, votos a Ciudadanos-Partido de la Ciudadanía',
#  'Elecciones municipales, votos al Partido Socialista Obrero Español',
#  'Elecciones municipales, votos a VOX',
#  'Centros de Servicios Sociales',
#  'Centros Municipales de Mayores ',
#  'Centros de Día de Alzheimer y Físicos',
#  'Apartamentos Municipales para Mayores',
#  'Residencias para personas Mayores ',
#  'Centros de Apoyo a las Familias (CAF)',
#  'Centros de Atención a la Infancia (CAI)',
#  'Centro de Día de Atención a Niños y Niñas (de 3 a 12 años)',
#  'Espacios de Ocio para Adolescentes (El Enredadero)',
#  'Centros de Adolescentes y Jóvenes (ASPA) ',
#  'Centros para personas sin hogar ',
#  'Espacios de Igualdad ',
#  'Centros Municipales de Salud Comunitaria (CMSC)',
#  'Centros de Atención a las Adicciones (CAD y CCAD)',
#  'Bibliotecas públicas Municipales',
#  'Bibliotecas públicas Comunidad Madrid',
#  'Centros y Espacios Culturales',
#  'Centros deportivos Municipales',
#  'Superficie deportiva m2 ',
#  'Instalaciones deportivas básicas',
#  'Instalaciones deportivas de acceso controlado ',
#  'Campos de fútbol 11',
#  'Pista de atletismo ',
#  'Piscinas cubiertas',
#  'Piscinas de verano',
#  'Superficie de zonas verdes y Parques de distrito (ha)',
#  'Relación de Superficie de zonas verdes y Parques de distrito (ha) entre número de Habitantes *10.000',
#  'Superficie de Parques Históricos, Singulares y Forestales por distrito  ',
#  'Superficie de Parques Históricos, Singulares y Forestales por distrito  entre número de Habitantes *10.000',
#  'Escuelas Infantiles Municipales',
#  'Escuelas Infantiles Públicas CAM ',
#  'Escuelas Infantiles Privadas                                ',
#  'Colegios Públicos Infantil y Primaria ',
#  'Institutos Públicos de Educación Secundaria',
#  'Colegios Privados Inf. o Pri. o Inf. y Pri.',
#  'Colegios Privados Inf., Pri. y Sec. o Pri. y Sec.',
#  'Mercados Municipales',
#  'Asociaciones culturales y casas regionales',
#  'Asociaciones de mujeres',
#  'Asociaciones vecinales',
#  'Asociaciones (Sección 1ª)',
#  'Fundaciones (Sección 2ª)',
#  'Índice de Vulnerabilidad Territorial ',
#  'Posición en el ranking de distritos y/o barrios de vulnerabilidad territorial',
#  'Superficie media de la vivienda (m2) en transacción',
#  'Primera y segunda nacionalidad extranjera en el Distrito: ITALIA (Población total Distrito)            ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: \nBANGLADESH (Población total Distrito)',
#  'Primera y segunda nacionalidad extranjera en el Distrito: FILIPINAS (Población total Distrito) ',
#  'Tasa bruta de natalidad (‰)',
#  'Renta neta media anual de los hogares (Urban Audit)                ',
#  'Crecimiento/decrecimiento Renta Bruta Per cápita 2017(a)-2008',
#  'Escolarización del alumnado por tipo de centro',
#  'Casos trabajados por el programa de absentismo municipal ',
#  'Sedentarismo',
#  'Sedentarismo Hombres ',
#  'Sedentarismo Mujeres ',
#  'Consumo de tabaco diario',
#  'Consumo de tabaco diario Hombres',
#  'Consumo de tabaco diario Mujeres ',
#  'Consumo de medicamentos ',
#  'Consumo de medicamentos Hombres  ',
#  'Consumo de medicamentos Mujeres ',
#  'Autopercepción de buen estado de salud  (porcentaje respuesta muy buena + buena)',
#  'Autopercepción de buen estado de salud           Hombres ',
#  'Autopercepción de buen estado de salud                   Mujeres ',
#  'Calidad de vida relacionada con la salud (CVRS) ',
#  'Calidad de vida relacionada con la salud (CVRS) Hombres',
#  'Calidad de vida relacionada con la salud (CVRS) Mujeres',
#  'Presencia de enfermedad crónica ',
#  'Presencia de enfermedad crónica        Hombres ',
#  'Presencia de enfermedad crónica            Mujeres',
#  'Hipertensión arterial',
#  'Hipertensión arterial         Hombres',
#  'Hipertensión arterial         Mujeres',
#  'Diabetes Mellitus',
#  'Diabetes Mellitus Hombres',
#  'Diabetes Mellitus Mujeres',
#  'Personas con obesidad ',
#  'Personas con obesidad Hombres ',
#  'Personas con obesidad Mujeres',
#  'Personas con sobrepeso',
#  'Personas con sobrepeso Hombres',
#  'Personas con sobrepeso Mujeres',
#  'Alguna dependencia funcional Hombres ',
#  'Alguna dependencia funcional Mujeres',
#  'Prevalencia de obesidad en la población infantil (2017. Estudio Madrid Salud. UCM)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)          (2018. EMS)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12) Hombres           (2018. EMS)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)  Mujeres           (2018. EMS)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12) Abril 2020',
#  'Probabilidad de padecer enfermedad mental (GHQ-12) Hombres Abril 2020',
#  'Probabilidad de padecer enfermedad mental (GHQ-12) Mujeres Abril 2020',
#  'Probabilidad de padecer enfermedad mental (GHQ-12) Octubre 2020',
#  'Probabilidad de padecer enfermedad mental (GHQ-12) Hombres Octubre 2020',
#  'Probabilidad de padecer enfermedad mental(GHQ-12)  Mujeres Octubre 2020',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 18-29 años (ENS, 2017)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 30-44 años (ENS, 2017)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 45-64 años (ENS, 2017)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 65 y más años (ENS, 2017)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 18-29 años (Abril, 2020)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 30-44 años (Abril, 2020)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 45-64 años (Abril, 2020)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 65 y más años (Abril, 2020)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 18-29 años  (Octubre, 2020)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 30-44 años  (Octubre, 2020)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 45-64 años  (Octubre, 2020)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 65 y más años (Octubre, 2020)',
#  'Grado de satisfacción con los espacios verdes',
#  'Grado de satisfacción con los parques infantiles ',
#  'Grado de satisfacción con los centros culturales',
#  'Grado de satisfacción con las instalaciones deportivas',
#  'Grado de satisfacción de los servicios sociales municipales',
#  'Grado de preferencia como medio de información de la actividad del Ayuntamiento: REDES SOCIALES',
#  'Madrid ciudad amigable con las personas lesbianas, gays, transexuales y bisexuales',
#  'Número de inmuebles de uso residencial ',
#  'Superficie media construida (m2) inmuebles de uso residencial',
#  'Año medio de contrucción de inmuebles de uso residencial ',
#  'Lanzamientos judiciales practicados',
#  'Dióxido de azufre - SO2 (µgr/m3)',
#  'Ozono - O3 (µgr/m3)',
#  'Inspecciones y actuaciones en locales de espectáculos públicos y actividades recreativas  ',
#  'Casos trabajados por el programa de absentismo municipal Hombres                        ',
#  'Casos trabajados por el programa de absentismo municipal Mujeres                                  ',
#  'Duración media del crédito (meses) en transacción de vivienda (2019) ',
#  'Índice de envejecimiento activo',
#  'Índice de envejecimiento activo en  Hombres ',
#  'Índice de envejecimiento activo en  Mujeres',
#  'Personas con nacionalidad española Mujeres                         ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: CHINA (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: VENEZUELA (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: FRANCIA (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: MARRUECOS (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: PARAGUAY (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: PERÚ (Población total Distrito) ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: COLOMBIA (Población total Distrito) ',
#  'Número de personas con grado de discapacidad reconocido Mujeres                                ',
#  'Medida en la que la ciudadanía se siente informada de lo que hace el Ayuntamiento',
#  'Madrid ciudad amigable con las personas lesbianas, gays, transexuales y bisexuales ',
#  'Superficie media de la vivienda (m2) en transacción                                                ',
#  'Partículas suspensión PM10 (µgr/m3)',
#  'Centro de Día de Atención a Niños y Niñas (de 3 a 12 años) ',
#  'Hogar Unipersonal, de personas de menos de 65 años. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#  'Hogar Unipersonal, de personas de menos de 65 años. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#  'Hogar Unipersonal, de personas de menos de 65 años. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#  'Hogar Unipersonal, de personas de  65 años o más. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#  'Hogar Unipersonal, de personas de  65 años o más. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#  'Hogar Unipersonal, de personas de  65 años o más. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#  'Hogares monoparentales. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#  'Hogares monoparentales. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#  'Hogares monoparentales. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#  'Hogares formados por pareja sin hijos/as. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#  'Hogares formados por pareja sin hijos/as. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#  'Hogares formados por pareja sin hijos/as. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#  'Hogares formados por pareja con hijos/as. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#  'Hogares formados por pareja con hijos/as. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#  'Hogares formados por pareja con hijos/as. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#  'Primera y segunda nacionalidad extranjera en el Distrito: HONDURAS (Población total Distrito) 2',
#  'Personas paradas que SÍ perciben prestaciones (febrero)      ',
#  'Superficie media construida (m2) inmuebles de uso residencial ',
#  'Primera y segunda nacionalidad extranjera en el Distrito: ITALIA (Total en Distrito)            ',
#  'Índice de Vulnerabilidad Territorial Agregado',
#  'Índice de Vulnerabilidad Bienestar Social e Igualdad',
#  'Índice de Vulnerabilidad Medio Ambiente Urbano y Movilidad',
#  'Índice de Vulnerabilidad Educación y Cultura',
#  'Índice de Vulnerabilidad Economía y Empleo',
#  'Índice de Vulnerabilidad Salud',
#  'Número de locales dados de alta totales',
#  'Número de locales dados de alta abiertos',
#  'Número de locales dados de alta cerrados',
#  'Número de locales dados de alta en obra',
#  'Número de locales dados de alta en uso como vivienda',
#  'Elecciones municipales, votos a Más Madrid-Verdes Equo',
#  'Elecciones municipales, votos a Podemos-Izquierda Unida-Alianza Verde',
#  'Índice de Vulnerabilidad Bienestar Social e Igualdad ',
#  'Índice de Vulnerabilidad Economía y Empleo ',
#  'Índice de Vulnerabilidad Educación y Cultura ',
#  'Índice de Vulnerabilidad Medio Ambiente Urbano y Movilidad ',
#  'Índice de Vulnerabilidad Salud ']

# %% [markdown]
# ## Selecting columns

# %%
madrid_df = madrid_df.select(['ciudad',
                              'distrito',
                              'barrio',
                              'año',
                              'Superficie (Ha.) ',
                              'Población densidad (hab./Ha.) ',
                              'Número Habitantes',
                              'Población Hombres ',
                              'Población Mujeres',
                              'Edad media de la población',
                              'Población de 0 a 14 años   ',
                              'Población de 15 a 29 años',
                              'Población de 30 a 44  años',
                              'Población de 45 a 64 años',
                              'Población de 65 a 79 años      ',
                              'Población de 80 años y más           ',
                              'Población de 65 años y más          ',
                              'Personas con nacionalidad española             ',
                              'Personas con nacionalidad española Hombres                      ',
                              'Personas con nacionalidad española Mujeres                      ',
                              'Personas con nacionalidad extranjera            ',
                              'Personas con nacionalidad extranjera Hombres                       ',
                              'Personas con nacionalidad extranjera Mujeres                        ',
                              'Renta neta media anual de los hogares (Urban Audit)             ',
                              'Renta disponible media por persona',
                              'Paro registrado (número de personas registradas en SEPE en febrero) ',
                              'Paro registrado (número de personas registradas en SEPE en febrero) hombres    ',
                              'Paro registrado (número de personas registradas en SEPE en febrero) mujeres',
                              'Tasa absoluta de paro registrado (febrero)',
                              'Tasa absoluta de paro registrado Mujeres',
                              'Tasa de desempleo en mujeres de 16 a 24 años',
                              'Tasa de desempleo en mujeres de 25 a 44 años',
                              'Tasa de desempleo en mujeres de 45 a 64 años',
                              'Tasa absoluta de paro registrado Hombres ',
                              'Tasa de desempleo en hombres de 16 a 24 años',
                              'Tasa de desempleo en hombres de 25 a 44 años',
                              'Tasa de desempleo en hombres de 45 a 64 años',
                              'Personas paradas de larga duración (febrero)              ',
                              'Personas paradas de larga duración (febrero) hombres                         ',
                              'Personas paradas de larga duración (febrero) mujeres                            ',
                              'Personas paradas que SÍ perciben prestaciones (febrero)',
                              'Personas paradas que SÍ perciben prestaciones (febrero) hombres                         ',
                              'Personas paradas que SÍ perciben prestaciones (febrero) mujeres                         ',
                              'Personas paradas que NO perciben prestaciones (febrero)',
                              'Personas paradas que NO perciben prestaciones (febrero) hombres          ',
                              'Personas paradas que NO perciben prestaciones (febrero) mujeres          ',
                              'Población en etapas educativas',
                              'Alumnado en Centros privados concertados',
                              'Alumnado en Centros privados sin concierto',
                              'Alumnado en Centros públicos',
                              'Total alumnado extranjero ',
                              'Alumnado extranjero en Centros privados concertados                   ',
                              'Alumnado extranjero en Centros privados sin concierto                  ',
                              'Alumnado extranjero en Centros públicos                        ',
                              'Total alumnado con necesidades de apoyo educativo  ',
                              'Alumnado con necesidades de apoyo educativo en Centros privados concertados                   ',
                              'Alumnado con necesidades de apoyo educativo en Centros privados sin concierto                  ',
                              'Alumnado con necesidades de apoyo educativo en Centros públicos                        ',
                              'Población mayor/igual  de 25 años  que no sabe leer ni escribir o sin estudios                ',
                              'Población mayor/igual  de 25 años con enseñanza primaria incompleta  ',
                              'Población mayor/igual  de 25 años con Bachiller Elemental, Graduado Escolar, ESO, Formación profesional 1º grado  ',
                              'Población mayor/igual  de 25 años con Formación profesional 2º grado, Bachiller Superior o BUP  ',
                              'Población mayor/igual  de 25 años con titulación media, diplomatura, arquitectura o ingeniería técnica    ',
                              'Población mayor/igual  de 25 años  con estudios superiores, licenciatura, arquitectura, ingeniería sup., estudios sup. no universitarios, doctorado,  postgraduado  ',
                              'Población mayor/igual  de 25 años con Nivel de estudios desconocido y/o no consta                                   ',
                              'Casos trabajados por el programa de absentismo municipal',
                              'Número de personas con grado de discapacidad reconocido                               ',
                              'Número de personas con grado de discapacidad reconocido Hombres                                    ',
                              'Número de personas con grado de discapacidad reconocido Mujeres                                    ',
                              'Satisfacción de vivir en su barrio ',
                              'Calidad de vida actual en su barrio ',
                              'Percepción de seguridad en Madrid',
                              'Percepción de seguridad en el barrio por el día',
                              'Percepción de seguridad en el barrio por la noche',
                              'Solicitudes tramitadas de Renta Mínima de Inserción',
                              'Personas perceptoras de prestación de la Renta Mínima de Inserción',
                              'Personas beneficiarias de prestaciones sociales de carácter económico',
                              'Total prestaciones sociales de carácter económico ',
                              'Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar)  ',
                              'Número Total de viviendas (Censo Edificios y Viviendas 2011)',
                              'Viviendas anteriores a 1980                                                                 ',
                              'Viviendas en estado ruinoso',
                              'Viviendas en estado malo ',
                              'Viviendas en estado deficiente  ',
                              'Viviendas en estado bueno ',
                              'Estado de la vivienda no consta ',
                              'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) ',
                              'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) Principal                           ',
                              'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Secundaria                           ',
                              'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Población desocupada    ',
                              'Intervenciones de la Policía Municipal en materia de seguridad: delitos relacionados con las personas',
                              'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia de armas',
                              'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con el patrimonio',
                              'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia y consumo de drogas',
                              'Atestados/partes de accidentes de tráfico confeccionados',
                              'Personas detenidas e investigadas por la Policía Municipal en materia de seguridad: Total  personas detenidas e investigadas ',
                              'Elecciones municipales, censo electoral',
                              'Elecciones municipales, abstenciones',
                              'Elecciones  municipales, votos en blanco',
                              'Elecciones municipales, votos a candidaturas',
                              'Elecciones municipales, votos a Más Madrid',
                              'Elecciones municipales, votos al Partido Popular',
                              'Elecciones municipales, votos a Ciudadanos-Partido de la Ciudadanía',
                              'Elecciones municipales, votos al Partido Socialista Obrero Español',
                              'Elecciones municipales, votos a VOX',
                              'Sedentarismo',
                              'Consumo de tabaco diario',
                              'Consumo de medicamentos ',
                              'Autopercepción de buen estado de salud  (porcentaje respuesta muy buena + buena)',
                              'Calidad de vida relacionada con la salud (CVRS) ',
                              'Presencia de enfermedad crónica ',
                              'Hipertensión arterial',
                              'Diabetes Mellitus',
                              'Personas con obesidad ',
                              'Personas con sobrepeso',
                              'Prevalencia de obesidad en la población infantil (2017. Estudio Madrid Salud. UCM)',
                              'Probabilidad de padecer enfermedad mental (GHQ-12)          (2018. EMS)',
                              'Grado de satisfacción con los espacios verdes',
                              'Grado de satisfacción con los parques infantiles ',
                              'Grado de satisfacción con los centros culturales',
                              'Grado de satisfacción con las instalaciones deportivas',
                              'Grado de satisfacción de los servicios sociales municipales',
                              'Superficie media construida (m2) inmuebles de uso residencial',
                              'Año medio de contrucción de inmuebles de uso residencial ',
                              'Total hogares',
                              'Tamaño medio del hogar      ',
                              'Hogares con una mujer sola mayor de 65 años                      ',
                              'Hogares con un hombre solo mayor de 65 años                     ',
                              'Hogares monoparentales: una mujer adulta con uno o más menores',
                              'Hogares monoparentales: un hombre adulto con uno o más menores',
                              'Tasa de crecimiento demográfico (porcentaje)',
                              'Esperanza de vida al nacer Mujeres',
                              'Esperanza de vida al nacer Hombres ',
                              'Esperanza de vida mayor de 65 años Mujeres',
                              'Esperanza de vida mayor de 65 años Hombres',
                              'Crecimiento/decrecimiento Renta Bruta Per cápita 2016(a)-2008',
                              'Pensión media mensual Hombres ',
                              'Pensión media mensual  Mujeres\n'
                              ])

# %% [markdown]
# ## Renaming columns

# %%
columns_renamed = [x.lstrip(' ').rstrip(' ') for x in madrid_df.columns]
madrid_df = madrid_df.rename(dict(zip(madrid_df.columns, columns_renamed)))

# %%
madrid_df.columns
# Out:
# ['ciudad',
#  'distrito',
#  'barrio',
#  'año',
#  'Superficie (Ha.)',
#  'Población densidad (hab./Ha.)',
#  'Número Habitantes',
#  'Población Hombres',
#  'Población Mujeres',
#  'Edad media de la población',
#  'Población de 0 a 14 años',
#  'Población de 15 a 29 años',
#  'Población de 30 a 44  años',
#  'Población de 45 a 64 años',
#  'Población de 65 a 79 años',
#  'Población de 80 años y más',
#  'Población de 65 años y más',
#  'Personas con nacionalidad española',
#  'Personas con nacionalidad española Hombres',
#  'Personas con nacionalidad española Mujeres',
#  'Personas con nacionalidad extranjera',
#  'Personas con nacionalidad extranjera Hombres',
#  'Personas con nacionalidad extranjera Mujeres',
#  'Renta neta media anual de los hogares (Urban Audit)',
#  'Renta disponible media por persona',
#  'Paro registrado (número de personas registradas en SEPE en febrero)',
#  'Paro registrado (número de personas registradas en SEPE en febrero) hombres',
#  'Paro registrado (número de personas registradas en SEPE en febrero) mujeres',
#  'Tasa absoluta de paro registrado (febrero)',
#  'Tasa absoluta de paro registrado Mujeres',
#  'Tasa de desempleo en mujeres de 16 a 24 años',
#  'Tasa de desempleo en mujeres de 25 a 44 años',
#  'Tasa de desempleo en mujeres de 45 a 64 años',
#  'Tasa absoluta de paro registrado Hombres',
#  'Tasa de desempleo en hombres de 16 a 24 años',
#  'Tasa de desempleo en hombres de 25 a 44 años',
#  'Tasa de desempleo en hombres de 45 a 64 años',
#  'Personas paradas de larga duración (febrero)',
#  'Personas paradas de larga duración (febrero) hombres',
#  'Personas paradas de larga duración (febrero) mujeres',
#  'Personas paradas que SÍ perciben prestaciones (febrero)',
#  'Personas paradas que SÍ perciben prestaciones (febrero) hombres',
#  'Personas paradas que SÍ perciben prestaciones (febrero) mujeres',
#  'Personas paradas que NO perciben prestaciones (febrero)',
#  'Personas paradas que NO perciben prestaciones (febrero) hombres',
#  'Personas paradas que NO perciben prestaciones (febrero) mujeres',
#  'Población en etapas educativas',
#  'Alumnado en Centros privados concertados',
#  'Alumnado en Centros privados sin concierto',
#  'Alumnado en Centros públicos',
#  'Total alumnado extranjero',
#  'Alumnado extranjero en Centros privados concertados',
#  'Alumnado extranjero en Centros privados sin concierto',
#  'Alumnado extranjero en Centros públicos',
#  'Total alumnado con necesidades de apoyo educativo',
#  'Alumnado con necesidades de apoyo educativo en Centros privados concertados',
#  'Alumnado con necesidades de apoyo educativo en Centros privados sin concierto',
#  'Alumnado con necesidades de apoyo educativo en Centros públicos',
#  'Población mayor/igual  de 25 años  que no sabe leer ni escribir o sin estudios',
#  'Población mayor/igual  de 25 años con enseñanza primaria incompleta',
#  'Población mayor/igual  de 25 años con Bachiller Elemental, Graduado Escolar, ESO, Formación profesional 1º grado',
#  'Población mayor/igual  de 25 años con Formación profesional 2º grado, Bachiller Superior o BUP',
#  'Población mayor/igual  de 25 años con titulación media, diplomatura, arquitectura o ingeniería técnica',
#  'Población mayor/igual  de 25 años  con estudios superiores, licenciatura, arquitectura, ingeniería sup., estudios sup. no universitarios, doctorado,  postgraduado',
#  'Población mayor/igual  de 25 años con Nivel de estudios desconocido y/o no consta',
#  'Casos trabajados por el programa de absentismo municipal',
#  'Número de personas con grado de discapacidad reconocido',
#  'Número de personas con grado de discapacidad reconocido Hombres',
#  'Número de personas con grado de discapacidad reconocido Mujeres',
#  'Satisfacción de vivir en su barrio',
#  'Calidad de vida actual en su barrio',
#  'Percepción de seguridad en Madrid',
#  'Percepción de seguridad en el barrio por el día',
#  'Percepción de seguridad en el barrio por la noche',
#  'Solicitudes tramitadas de Renta Mínima de Inserción',
#  'Personas perceptoras de prestación de la Renta Mínima de Inserción',
#  'Personas beneficiarias de prestaciones sociales de carácter económico',
#  'Total prestaciones sociales de carácter económico',
#  'Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar)',
#  'Número Total de viviendas (Censo Edificios y Viviendas 2011)',
#  'Viviendas anteriores a 1980',
#  'Viviendas en estado ruinoso',
#  'Viviendas en estado malo',
#  'Viviendas en estado deficiente',
#  'Viviendas en estado bueno',
#  'Estado de la vivienda no consta',
#  'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)',
#  'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) Principal',
#  'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Secundaria',
#  'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Población desocupada',
#  'Intervenciones de la Policía Municipal en materia de seguridad: delitos relacionados con las personas',
#  'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia de armas',
#  'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con el patrimonio',
#  'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia y consumo de drogas',
#  'Atestados/partes de accidentes de tráfico confeccionados',
#  'Personas detenidas e investigadas por la Policía Municipal en materia de seguridad: Total  personas detenidas e investigadas',
#  'Elecciones municipales, censo electoral',
#  'Elecciones municipales, abstenciones',
#  'Elecciones  municipales, votos en blanco',
#  'Elecciones municipales, votos a candidaturas',
#  'Elecciones municipales, votos a Más Madrid',
#  'Elecciones municipales, votos al Partido Popular',
#  'Elecciones municipales, votos a Ciudadanos-Partido de la Ciudadanía',
#  'Elecciones municipales, votos al Partido Socialista Obrero Español',
#  'Elecciones municipales, votos a VOX',
#  'Sedentarismo',
#  'Consumo de tabaco diario',
#  'Consumo de medicamentos',
#  'Autopercepción de buen estado de salud  (porcentaje respuesta muy buena + buena)',
#  'Calidad de vida relacionada con la salud (CVRS)',
#  'Presencia de enfermedad crónica',
#  'Hipertensión arterial',
#  'Diabetes Mellitus',
#  'Personas con obesidad',
#  'Personas con sobrepeso',
#  'Prevalencia de obesidad en la población infantil (2017. Estudio Madrid Salud. UCM)',
#  'Probabilidad de padecer enfermedad mental (GHQ-12)          (2018. EMS)',
#  'Grado de satisfacción con los espacios verdes',
#  'Grado de satisfacción con los parques infantiles',
#  'Grado de satisfacción con los centros culturales',
#  'Grado de satisfacción con las instalaciones deportivas',
#  'Grado de satisfacción de los servicios sociales municipales',
#  'Superficie media construida (m2) inmuebles de uso residencial',
#  'Año medio de contrucción de inmuebles de uso residencial',
#  'Total hogares',
#  'Tamaño medio del hogar',
#  'Hogares con una mujer sola mayor de 65 años',
#  'Hogares con un hombre solo mayor de 65 años',
#  'Hogares monoparentales: una mujer adulta con uno o más menores',
#  'Hogares monoparentales: un hombre adulto con uno o más menores',
#  'Tasa de crecimiento demográfico (porcentaje)',
#  'Esperanza de vida al nacer Mujeres',
#  'Esperanza de vida al nacer Hombres',
#  'Esperanza de vida mayor de 65 años Mujeres',
#  'Esperanza de vida mayor de 65 años Hombres',
#  'Crecimiento/decrecimiento Renta Bruta Per cápita 2016(a)-2008',
#  'Pensión media mensual Hombres',
#  'Pensión media mensual  Mujeres\n']

# %% [markdown]
# ## Reformating strings to numbers

# %%
for col in madrid_df.columns:
    try:
        madrid_df = madrid_df.with_columns(pl.col(col)\
                         .map_elements(lambda x: reformat_str_number(x))\
                         .cast(pl.Float64).round(2))
    except:
        print(f'{col} not allow the transformation.')
# Out:
# distrito not allow the transformation.
# barrio not allow the transformation.
# año not allow the transformation.
# Superficie (Ha.) not allow the transformation.
# Población densidad (hab./Ha.) not allow the transformation.
# Número Habitantes not allow the transformation.
# Población Hombres not allow the transformation.
# Población Mujeres not allow the transformation.
# Edad media de la población not allow the transformation.
# Población de 0 a 14 años not allow the transformation.
# Población de 15 a 29 años not allow the transformation.
# Población de 30 a 44  años not allow the transformation.
# Población de 45 a 64 años not allow the transformation.
# Población de 65 a 79 años not allow the transformation.
# Población de 80 años y más not allow the transformation.
# Población de 65 años y más not allow the transformation.
# Personas con nacionalidad española not allow the transformation.
# Personas con nacionalidad española Hombres not allow the transformation.
# Personas con nacionalidad española Mujeres not allow the transformation.
# Personas con nacionalidad extranjera not allow the transformation.
# Personas con nacionalidad extranjera Hombres not allow the transformation.
# Personas con nacionalidad extranjera Mujeres not allow the transformation.
# Renta neta media anual de los hogares (Urban Audit) not allow the transformation.
# Renta disponible media por persona not allow the transformation.
# Paro registrado (número de personas registradas en SEPE en febrero) not allow the transformation.
# Paro registrado (número de personas registradas en SEPE en febrero) hombres not allow the transformation.
# Paro registrado (número de personas registradas en SEPE en febrero) mujeres not allow the transformation.
# Tasa absoluta de paro registrado (febrero) not allow the transformation.
# Tasa absoluta de paro registrado Mujeres not allow the transformation.
# Tasa de desempleo en mujeres de 16 a 24 años not allow the transformation.
# Tasa de desempleo en mujeres de 25 a 44 años not allow the transformation.
# Tasa de desempleo en mujeres de 45 a 64 años not allow the transformation.
# Tasa absoluta de paro registrado Hombres not allow the transformation.
# Tasa de desempleo en hombres de 16 a 24 años not allow the transformation.
# Tasa de desempleo en hombres de 25 a 44 años not allow the transformation.
# Tasa de desempleo en hombres de 45 a 64 años not allow the transformation.
# Personas paradas de larga duración (febrero) not allow the transformation.
# Personas paradas de larga duración (febrero) hombres not allow the transformation.
# Personas paradas de larga duración (febrero) mujeres not allow the transformation.
# Personas paradas que SÍ perciben prestaciones (febrero) not allow the transformation.
# Personas paradas que SÍ perciben prestaciones (febrero) hombres not allow the transformation.
# Personas paradas que SÍ perciben prestaciones (febrero) mujeres not allow the transformation.
# Personas paradas que NO perciben prestaciones (febrero) not allow the transformation.
# Personas paradas que NO perciben prestaciones (febrero) hombres not allow the transformation.
# Personas paradas que NO perciben prestaciones (febrero) mujeres not allow the transformation.
# Población en etapas educativas not allow the transformation.
# Alumnado en Centros privados concertados not allow the transformation.
# Alumnado en Centros privados sin concierto not allow the transformation.
# Alumnado en Centros públicos not allow the transformation.
# Total alumnado extranjero not allow the transformation.
# Alumnado extranjero en Centros privados concertados not allow the transformation.
# Alumnado extranjero en Centros privados sin concierto not allow the transformation.
# Alumnado extranjero en Centros públicos not allow the transformation.
# Total alumnado con necesidades de apoyo educativo not allow the transformation.
# Alumnado con necesidades de apoyo educativo en Centros privados concertados not allow the transformation.
# Alumnado con necesidades de apoyo educativo en Centros privados sin concierto not allow the transformation.
# Alumnado con necesidades de apoyo educativo en Centros públicos not allow the transformation.
# Población mayor/igual  de 25 años  que no sabe leer ni escribir o sin estudios not allow the transformation.
# Población mayor/igual  de 25 años con enseñanza primaria incompleta not allow the transformation.
# Población mayor/igual  de 25 años con Bachiller Elemental, Graduado Escolar, ESO, Formación profesional 1º grado not allow the transformation.
# Población mayor/igual  de 25 años con Formación profesional 2º grado, Bachiller Superior o BUP not allow the transformation.
# Población mayor/igual  de 25 años con titulación media, diplomatura, arquitectura o ingeniería técnica not allow the transformation.
# Población mayor/igual  de 25 años  con estudios superiores, licenciatura, arquitectura, ingeniería sup., estudios sup. no universitarios, doctorado,  postgraduado not allow the transformation.
# Población mayor/igual  de 25 años con Nivel de estudios desconocido y/o no consta not allow the transformation.
# Casos trabajados por el programa de absentismo municipal not allow the transformation.
# Número de personas con grado de discapacidad reconocido not allow the transformation.
# Número de personas con grado de discapacidad reconocido Hombres not allow the transformation.
# Número de personas con grado de discapacidad reconocido Mujeres not allow the transformation.
# Satisfacción de vivir en su barrio not allow the transformation.
# Calidad de vida actual en su barrio not allow the transformation.
# Percepción de seguridad en Madrid not allow the transformation.
# Percepción de seguridad en el barrio por el día not allow the transformation.
# Percepción de seguridad en el barrio por la noche not allow the transformation.
# Solicitudes tramitadas de Renta Mínima de Inserción not allow the transformation.
# Personas perceptoras de prestación de la Renta Mínima de Inserción not allow the transformation.
# Personas beneficiarias de prestaciones sociales de carácter económico not allow the transformation.
# Total prestaciones sociales de carácter económico not allow the transformation.
# Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar) not allow the transformation.
# Número Total de viviendas (Censo Edificios y Viviendas 2011) not allow the transformation.
# Viviendas anteriores a 1980 not allow the transformation.
# Viviendas en estado ruinoso not allow the transformation.
# Viviendas en estado malo not allow the transformation.
# Viviendas en estado deficiente not allow the transformation.
# Viviendas en estado bueno not allow the transformation.
# Estado de la vivienda no consta not allow the transformation.
# Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) not allow the transformation.
# Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) Principal not allow the transformation.
# Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Secundaria not allow the transformation.
# Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Población desocupada not allow the transformation.
# Intervenciones de la Policía Municipal en materia de seguridad: delitos relacionados con las personas not allow the transformation.
# Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia de armas not allow the transformation.
# Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con el patrimonio not allow the transformation.
# Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia y consumo de drogas not allow the transformation.
# Atestados/partes de accidentes de tráfico confeccionados not allow the transformation.
# Personas detenidas e investigadas por la Policía Municipal en materia de seguridad: Total  personas detenidas e investigadas not allow the transformation.
# Elecciones municipales, censo electoral not allow the transformation.
# Elecciones municipales, abstenciones not allow the transformation.
# Elecciones  municipales, votos en blanco not allow the transformation.
# Elecciones municipales, votos a candidaturas not allow the transformation.
# Elecciones municipales, votos a Más Madrid not allow the transformation.
# Elecciones municipales, votos al Partido Popular not allow the transformation.
# Elecciones municipales, votos a Ciudadanos-Partido de la Ciudadanía not allow the transformation.
# Elecciones municipales, votos al Partido Socialista Obrero Español not allow the transformation.
# Elecciones municipales, votos a VOX not allow the transformation.
# Sedentarismo not allow the transformation.
# Consumo de tabaco diario not allow the transformation.
# Consumo de medicamentos not allow the transformation.
# Autopercepción de buen estado de salud  (porcentaje respuesta muy buena + buena) not allow the transformation.
# Calidad de vida relacionada con la salud (CVRS) not allow the transformation.
# Presencia de enfermedad crónica not allow the transformation.
# Hipertensión arterial not allow the transformation.
# Diabetes Mellitus not allow the transformation.
# Personas con obesidad not allow the transformation.
# Personas con sobrepeso not allow the transformation.
# Prevalencia de obesidad en la población infantil (2017. Estudio Madrid Salud. UCM) not allow the transformation.
# Probabilidad de padecer enfermedad mental (GHQ-12)          (2018. EMS) not allow the transformation.
# Grado de satisfacción con los espacios verdes not allow the transformation.
# Grado de satisfacción con los parques infantiles not allow the transformation.
# Grado de satisfacción con los centros culturales not allow the transformation.
# Grado de satisfacción con las instalaciones deportivas not allow the transformation.
# Grado de satisfacción de los servicios sociales municipales not allow the transformation.
# Superficie media construida (m2) inmuebles de uso residencial not allow the transformation.
# Año medio de contrucción de inmuebles de uso residencial not allow the transformation.
# Total hogares not allow the transformation.
# Tamaño medio del hogar not allow the transformation.
# Hogares con una mujer sola mayor de 65 años not allow the transformation.
# Hogares con un hombre solo mayor de 65 años not allow the transformation.
# Hogares monoparentales: una mujer adulta con uno o más menores not allow the transformation.
# Hogares monoparentales: un hombre adulto con uno o más menores not allow the transformation.
# Tasa de crecimiento demográfico (porcentaje) not allow the transformation.
# Esperanza de vida al nacer Mujeres not allow the transformation.
# Esperanza de vida al nacer Hombres not allow the transformation.
# Esperanza de vida mayor de 65 años Mujeres not allow the transformation.
# Esperanza de vida mayor de 65 años Hombres not allow the transformation.
# Crecimiento/decrecimiento Renta Bruta Per cápita 2016(a)-2008 not allow the transformation.
# Pensión media mensual Hombres not allow the transformation.
# Pensión media mensual  Mujeres
#  not allow the transformation.
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\
# C:\Users\fscielzo\AppData\Local\Temp\ipykernel_22840\2950448291.py:3: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   madrid_df = madrid_df.with_columns(pl.col(col)\

# %% [markdown]
# ## Getting 'Ciudad de Madrid' data

# %%
ciudad_madrid_df = madrid_df.filter(pl.col('distrito').is_null()).select(pl.exclude(['distrito', 'barrio']))

# %%
ciudad_madrid_df
# Out:
# shape: (12, 136)
# ┌────────────┬──────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ ciudad     ┆ año  ┆ Superficie ┆ Población  ┆ … ┆ Esperanza  ┆ Crecimien ┆ Pensión   ┆ Pensión   │
# │ ---        ┆ ---  ┆ (Ha.)      ┆ densidad   ┆   ┆ de vida    ┆ to/decrec ┆ media     ┆ media     │
# │ str        ┆ i64  ┆ ---        ┆ (hab./Ha.) ┆   ┆ mayor de   ┆ imiento   ┆ mensual   ┆ mensual   │
# │            ┆      ┆ str        ┆ ---        ┆   ┆ 65 años    ┆ Renta     ┆ Hombres   ┆ Mujeres   │
# │            ┆      ┆            ┆ str        ┆   ┆ Hombres    ┆ Bruta Per ┆ ---       ┆           │
# │            ┆      ┆            ┆            ┆   ┆ ---        ┆ cápita 2… ┆ str       ┆ ---       │
# │            ┆      ┆            ┆            ┆   ┆ str        ┆ ---       ┆           ┆ str       │
# │            ┆      ┆            ┆            ┆   ┆            ┆ str       ┆           ┆           │
# ╞════════════╪══════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ Ciudad de  ┆ 2019 ┆ 60.446     ┆ 54         ┆ … ┆ 20,9       ┆ null      ┆ 1.477     ┆ 988       │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2018 ┆ null       ┆ null       ┆ … ┆ 21         ┆ null      ┆ 1.456     ┆ 954       │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2016 ┆ null       ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2008 ┆ null       ┆ null       ┆ … ┆ null       ┆ 658       ┆ null      ┆ null      │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2020 ┆ null       ┆ null       ┆ … ┆ 17,7       ┆ null      ┆ 1.522     ┆ 1.146     │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2013 ┆ null       ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2021 ┆ 60.446     ┆ 55,17      ┆ … ┆ 20,1       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2009 ┆ null       ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2017 ┆ null       ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2022 ┆ 60.446     ┆ 55,39      ┆ … ┆ null       ┆ null      ┆ 1.584     ┆ 1.215     │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2023 ┆ 60.445,51  ┆ 55,26      ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Ciudad de  ┆ 2011 ┆ null       ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ Madrid     ┆      ┆            ┆            ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Getting 'distritos' data

# %%
distritos_madrid_df = madrid_df.filter(pl.col('barrio').is_null()).select(pl.exclude('barrio'))

# %%
distritos_madrid_df

# %% [markdown]
# ## Getting 'barrios' data

# %%
barrios_madrid_df = madrid_df.filter(~ pl.col('barrio').is_null())

# %%
barrios_madrid_df

# %%
columns_to_modify_type = [x for x in distritos_df.columns if x not in ['distrito', 'año']]
for col in columns_to_modify_type:
    distritos_df = distritos_df.with_columns(pl.col(col)\
                               .map_elements(lambda x: reformat_str_number(x))\
                               .cast(pl.Float64).round(2))

replace_dict = {x: find_most_similar_string(unidecode(x.lower().title()), candidates=distritos_geojson) for x in distritos_df['distrito'].drop_nulls().unique().to_list()}
distritos_df = distritos_df.with_columns(pl.col('distrito').replace(replace_dict).alias('distrito'))

columns_to_agg = [x for x in distritos_df.columns if x not in ['distrito', 'año']]
distritos_grouped_df = distritos_df.group_by(['distrito']).agg(pl.col(columns_to_agg).mean().round(2))
district_data[csv_name] = distritos_grouped_df

# %%
distritos_df.head(7)

# %%
distritos_df['año'].unique()

# %%
distritos_grouped_df.head()
